# %%
import os
import shutil

# %%
for i in os.listdir('data'):
    newname = i.replace(' ', '_')
    oldname = os.path.join('data/', i)
    newname = os.path.join('data/', newname)
    print(f'filename: {i}\npathname: {newname}\n')
#     os.rename(oldname, newname)
# Out:
# filename: 1.2.840.113619.2.55.3.2831165733.630.1414467641.996.txt
# pathname: data/1.2.840.113619.2.55.3.2831165733.630.1414467641.996.txt
#
# filename: 1.2.840.113619.2.55.3.2831165733.630.1414467641.996.csv
# pathname: data/1.2.840.113619.2.55.3.2831165733.630.1414467641.996.csv
#
# filename: 1.2.840.113619.2.81.290.1.4453.20140425.211004.csv
# pathname: data/1.2.840.113619.2.81.290.1.4453.20140425.211004.csv
#
# filename: 1.2.840.113619.2.278.3.2831165736.321.1359168013.722.csv
# pathname: data/1.2.840.113619.2.278.3.2831165736.321.1359168013.722.csv
#
# filename: 1.2.840.113619.2.55.3.2831165733.676.1374804516.774.txt
# pathname: data/1.2.840.113619.2.55.3.2831165733.676.1374804516.774.txt
#
# filename: 1.2.840.113619.2.278.3.2831165729.817.1444934184.806.csv
# pathname: data/1.2.840.113619.2.278.3.2831165729.817.1444934184.806.csv
#
# filename: 1.2.840.113619.2.278.3.2831165735.939.1301101022.989.txt
# pathname: data/1.2.840.113619.2.278.3.2831165735.939.1301101022.989.txt
#
# ...

# %%
import pandas as pd

df = pd.read_csv('/home/FRACTAL/devender.prasad/Desktop/Dave/data.csv')
print(df.head())
"""bool_value_1=df.loc[df["GT"]==1]
print(bool_value_1)"""
# Out:
#    Sr.      SeriesUID       StudyUID  GT  Predicted
# 0    0  ID_033b38d78d  ID_00166cfced   0   0.721117
# 1    1  ID_0c5c74fd76  ID_0049b51414   0   0.008068
# 2    2  ID_0aa094d75f  ID_008d0f4e79   0   0.072903
# 3    3  ID_0000298a7d  ID_00b9e1961f   0   0.171272
# 4    4  ID_0fad7b4743  ID_00cb7922be   1   0.942084
# 'bool_value_1=df.loc[df["GT"]==1]\nprint(bool_value_1)'

# %%
for i in os.listdir('data'):
    txt_file = f'data/{i}'
    csv_file = txt_file.replace('.txt', '.csv')
    print(f'txt: {txt_file}\ncsv: {csv_file}\n')
    print(csv_file)
    if os.exists(csv_file):sv_file
    shutil.copy(txt_file, csv_file)
# Out:
# txt: data/1.2.840.113619.2.55.3.2831165733.630.1414467641.996.txt
# csv: data/1.2.840.113619.2.55.3.2831165733.630.1414467641.996.csv
#
# data/1.2.840.113619.2.55.3.2831165733.630.1414467641.996.csv
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-a45701fb8434> in <module>()
#       4     print(f'txt: {txt_file}\ncsv: {csv_file}\n')
#       5     print(csv_file)
# ----> 6     if os.exists(csv_file):sv_file
#       7     shutil.copy(txt_file, csv_file)
#
# AttributeError: module 'os' has no attribute 'exists'

# %%
import os
import shutil
files_dir=r'C:\Users\dave\Desktop\python\folder2'
#print(os.getcwd())
dest_1='C:/Users/dave/Desktop/python/Az/1'
dest_2='C:/Users/dave/Desktop/python/Az/2'
dest_3='C:/Users/dave/Desktop/python/Az/3'
dest_4='C:/Users/dave/Desktop/python/Az/4'
dest_5='C:/Users/dave/Desktop/python/Az/5'

Dest = [dest_1,dest_1,dest_2,dest_2,dest_3,dest_3,dest_4,dest_4,dest_5,dest_5]

source = os.listdir(files_dir)
sorted_source = sorted(source)

for num,file in enumerate(sorted_source):
    full_path = os.path.join(files_dir,file)
    getting_dest_dir = num % 10
    target_folder = Dest[getting_dest_dir]
    shutil.copy(full_path,target_folder)

# %%
import os
import shutil
files_dir='data/'
print(os.getcwd(), '\n')
# dest_1='/set_1'
# dest_2='/set_2'
# dest_3='/set_3'
# dest_4='/set_4'
# dest_5='/set_5'

# Dest = [dest_1,dest_1,dest_2,dest_2,dest_3,dest_3,dest_4,dest_4,dest_5,dest_5]
sets = [f'set_{n}/' for n in range(1,6)]

source = os.listdir(files_dir)
sorted_source = sorted(source)

# num = 1

for num, file in enumerate(sorted_source):
#     getting_dest_dir = (i % num == 0) 
#     print(i, num, getting_dest_dir)
#     num += 1
    
#     if file.endswith('.csv'):

#         csv_file = os.path.join(files_dir, file)
#         txt_file = csv_file.replace('.csv', '.txt')
#         target_folder = sets[getting_dest_dir]

#         print(f'csv_file: {csv_file}\ntarget_folder: {target_folder}\n')
#         print(f'txt_file: {txt_file}\ntarget_folder: {target_folder}\n')
    
    full_path = os.path.join(files_dir,file)
    getting_dest_dir = num % 10
    target_folder = sets[getting_dest_dir]
#     shutil.copy(full_path,target_folder)
    print(f'full_path: {full_path}\ntarget_folder: {target_folder}\n')

# %%
sets = [f'set_{n}' for n in range(1,6)]
print(sets)

# %%
! ls

# %%
source

# %%
import os
import shutil
files_dir='data/'
print(os.getcwd(), '\n')
# dest_1='/set_1'
# dest_2='/set_2'
# dest_3='/set_3'
# dest_4='/set_4'
# dest_5='/set_5'

# Dest = [dest_1,dest_1,dest_2,dest_2,dest_3,dest_3,dest_4,dest_4,dest_5,dest_5]
sets = [f'set_{n}/' for n in range(1,6)]

source = os.listdir(files_dir)
sorted_source = sorted(source)


for num, file in enumerate(sorted_source):
     if ((num % 5)/2) == 0:
        getting_dest_dir= (num % 5)
        target_folder = sets[getting_dest_dir]
        
    else :
        getting_dest_dir= ((num-1) % 5)
        target_folder = sets[getting_dest_dir]
        
        
        
    print(a)
        
#     getting_dest_dir = (i % 5 == 0) 
#     print(i, num, getting_dest_dir)
#     num += 1
    
#     if file.endswith('.csv'):

#         csv_file = os.path.join(files_dir, file)
#         txt_file = csv_file.replace('.csv', '.txt')
#         target_folder = sets[getting_dest_dir]

# %%
import os
import shutil

# %%
! ls

# %%
path = 'data/'

# [os.mkdir(f'set_{x}') for x in range(1,6)]  # Once executed, comment it

num = 5

for i, file_ in enumerate(os.listdir(path)):
    if file_.endswith('.txt'):
        n = i % num

        txt_file = os.path.join(path, file_)
        csv_file = txt_file.replace('.txt', '.csv')
        dest_dir = f'set_{n + 1}/'

#         shutil.copy(txt_file, dest_dir)  # Once executed, comment it
#         shutil.copy(csv_file, dest_dir)  # Once executed, comment it
        print(f'txt_file: {txt_file}\ncsv_file: {csv_file}\ndest_dir: {dest_dir}\n')

# %%
import os 
for i in range(6):
    os.mkdir(f"true{i}")

# %%
for i in os.listdir('data'):
    txt_file = f'data/{i}'
    csv_file = txt_file.replace('.txt', '.csv')
    print(f'txt: {txt_file}\ncsv: {csv_file}\n')
    if 
        shutil.copy(txt_file, csv_file)

# %%
ls
