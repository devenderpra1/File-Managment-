# %%
import os
import shutil
import glob

# %%
path = 'data/'

#[os.mkdir(f'set_{x}') for x in range(1,6)]  # Once executed, comment it


n = 0

for file in os.listdir(path):
    
    if file.endswith('.txt'):
        
        if n == 5:
            n=0 
        
        txt_file = os.path.join(path, file)
        search = file.strip(".txt")
        dest_dir = f'set_{n+1}/'  
        
               
        for file_name in os.listdir(path):
            if search in file_name:
                if not file_name == file:
                    
                    pair_name = os.path.join(path, file_name) 
                    print(f'txt_file: {file}\npair_file: {file_name}\ndest_dir: {dest_dir}\n')
                    n += 1

                    
                    
                    
                    
#             print(f'filename:{file_name}')

#                 if search in file_name :
#                     print(f'txt_file: {txt_file}\ncsv_file: {csv_file}\ndest_dir: {dest_dir}\n')
#                     shutil.copy(txt_file, dest_dir)  # Once executed, comment it
#                     shutil.copy(csv_file, dest_dir)  # Once executed, comment it

            
# csv_file = txt_file.replace('.txt', '.csv')
# dest_dir = f'set_{n + 1}/'

#         shutil.copy(txt_file, dest_dir)  # Once executed, comment it
#         shutil.copy(csv_file, dest_dir)  # Once executed, comment it
#         print(f'txt_file: {txt_file}\ncsv_file: {csv_file}\ndest_dir: {dest_dir}\n')

# %%
# path = 'data/'

# # [os.mkdir(f'set_{x}') for x in range(1,6)]  # Once executed, comment it

# num = 5

# for i, file_ in enumerate(os.listdir(path)):
# #    print(file_)
#     if file_.endswith('.txt'):
#         n = i % num
#         txt_file = os.path.join(path, file_)
#         csv_file = txt_file.replace('.txt','.csv')
#         dest_dir = f'set_{n + 1}/'
#         print(txt_file)
#         print(csv_file)
#         for file_name in os.listdir(path):
#             if file_name.endswith('.csv'):
#                 print(file_name)
#                 if csv_file in file_name :
#                     name  = csv_file
#                     print(f'txt_file: {txt_file}\ncsv_file: {csv_file}\ndest_dir: {dest_dir}\n')

#         shutil.copy(txt_file, dest_dir)  # Once executed, comment it
#         shutil.copy(csv_file, dest_dir)  # Once executed, comment it
#           print(f'txt_file: {txt_file}\ncsv_file: {csv_file}\ndest_dir: {dest_dir}\n')

# %%
# for i in os.listdir('data/'): print(i)

# %%
#transfer file from a folder to another folder 
path = 'data/'
dest = 'set_1'
for file_name in os.listdir(f{(path).txt}:
    shutil.copy(file_name,dest)

# %%
path = 'data/'
for num,file in enumerate(glob.glob('data/*.txt')):
    file_name=(os.path.basename(file))
    file_strip=file_name.strip(".txt")
    other_file=f'data/default_VOIs_{file_strip}'
    n = num % 5
    dest_dir = f'set_{n + 1}/'2 years ago
￼examples.desktop3 months ago
￼file_name.py
    shutil.copy(file, dest_dir)  
    shutil.copy(other_file, dest_dir)
    print(f'file_txt: {file}\npre_file: {other_file}\ndest_dir: {dest_dir}\n')
# Out:
# file_txt: data/1.2.840.113619.2.55.3.2831165733.630.1414467641.996.txt
# pre_file: data/default_VOIs_1.2.840.113619.2.55.3.2831165733.630.1414467641.996
# dest_dir: set_1/
#
# file_txt: data/1.2.840.113619.2.55.3.2831165733.676.1374804516.774.txt
# pre_file: data/default_VOIs_1.2.840.113619.2.55.3.2831165733.676.1374804516.774
# dest_dir: set_2/
#
# file_txt: data/1.2.840.113619.2.278.3.2831165735.939.1301101022.989.txt
# pre_file: data/default_VOIs_1.2.840.113619.2.278.3.2831165735.939.1301101022.989
# dest_dir: set_3/
#
# file_txt: data/1.2.840.113619.2.25.4.2021121.1370843191.9.txt
# pre_file: data/default_VOIs_1.2.840.113619.2.25.4.2021121.1370843191.9
# dest_dir: set_4/
#
# file_txt: data/1.2.840.113619.2.55.3.2831165735.345.1442150210.616.txt
# pre_file: data/default_VOIs_1.2.840.113619.2.55.3.2831165735.345.1442150210.616
# dest_dir: set_5/
#
# file_txt: data/1.2.840.113619.2.55.3.2831165733.30.1421202381.857.txt
# ...

# %%
path = 'data/'
for num,file in enumerate(glob.glob('data/[d]*')):
    print(file)
    mirror_txt = file.strip("data/default_VOIs_")
    print(mirror_txt)
    n = num % 5
    dest_dir = f'set_{n+1}/'

# %%
! ls set_1/
# Out:
# 1.2.840.113619.2.278.3.2831165729.817.1444934184.806.txt
# 1.2.840.113619.2.278.3.2831165735.59.1321559413.136.txt
# 1.2.840.113619.2.278.3.2831165735.620.1353404774.435.txt
# 1.2.840.113619.2.278.3.2831165735.957.1343101233.79.txt
# 1.2.840.113619.2.278.3.2831165736.339.1360179560.597.txt
# 1.2.840.113619.2.55.3.2831165733.29.1416880600.651.txt
# 1.2.840.113619.2.55.3.2831165733.30.1421202381.857.txt
# 1.2.840.113619.2.55.3.2831165733.630.1414467641.996.txt
# 1.2.840.113619.2.81.290.1.2928.20140219.252055.txt
# 1.2.840.113619.2.81.290.1.5834.20141128.110321.txt
# default_VOIs_1.2.840.113619.2.278.3.2831165729.817.1444934184.806
# default_VOIs_1.2.840.113619.2.278.3.2831165735.59.1321559413.136
# default_VOIs_1.2.840.113619.2.278.3.2831165735.620.1353404774.435
# default_VOIs_1.2.840.113619.2.278.3.2831165735.957.1343101233.79
# default_VOIs_1.2.840.113619.2.278.3.2831165736.339.1360179560.597
# default_VOIs_1.2.840.113619.2.55.3.2831165733.29.1416880600.651
# ...

# %%
for i in range(1,6): 
    os.mkdir(f'set_{i}')

# %%
! ls
# Out:
# data  Move_files.ipynb	set_1  set_2  set_3  set_4  set_5
